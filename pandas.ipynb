# %%
import os
import pandas as pd

# %%
#从文件夹和信息表中取交集生成新表
file_path = r'\\mega\syli\dataset\neimo\eaoc'
label_path = r'\\mega\syli\dataset\neimo\label.xlsx'
file_df = pd.DataFrame(os.listdir(file_path), columns=['MRI-ID'])
label_df = pd.read_excel(label_path)
fin_df = pd.merge(file_df, label_df)
fin_df.rename(columns={'MRI-ID':'CaseName','MT':'label'},inplace=True)
fin_df.to_csv(r'\\mega\syli\dataset\neimo\label1.csv',index=False,encoding="utf_8_sig")

# %%
#合并label和feature
path=r'\\219.228.149.7\syli\dataset\Primary and metastatic\zheci\yfy Primary and metastatic-seg\dataframe'
df1=pd.read_csv(path + '\\all.csv') #可设置stp
savepath = r'\\219.228.149.7\syli\dataset\Primary and metastatic\zheci'
# df1['ID'] = df1['ID'].astype(dtype='str')
# df1.rename(columns={'name':'CaseName'},inplace=True)
df1['CaseName'] = df1['CaseName'].astype(dtype='str')
for modal in ['t1', 'dwi', 't2', 'T1CE']:
    
    df2=pd.read_csv(path+f'\\{modal}.csv')
    df2['CaseName'] = df2['CaseName'].astype(dtype='str')
    df5=pd.merge(df1,df2)   #合并数据表,需要共同的列
    #df2.insert(1,'label',df3)  #插入列
    if len(df5['CaseName']) != len(df1['CaseName']):
        print(modal)
#     df5.sort_values(by="time",axis=0,ascending=True,inplace=True)
#     df5.drop('time', axis = 1, inplace = True)
#     print(df5.head())
#     df3 = df5.iloc[:110,:]
#     df4 = df5.iloc[110:,:]
#     df3.to_csv(path + f'\\{modal}\\train.csv',index=False,encoding="utf_8_sig")
#     df4.to_csv(path + f'\\{modal}\\test.csv',index=False,encoding="utf_8_sig")
    df5.to_csv(savepath + f'\\{modal}\\{modal}.csv',index=False,encoding="utf_8_sig")
    #os.mkdir(r'\\mega\syli\dataset\endometrial cancer\data' + f'\\{modal}_result')

# %%
#print(list(set(b).difference(set(a))))
df4
# Out:
#          time       CaseName  sex  age  label  \
# 108  20180731  wangrongchang    1   69      0
# 109  20180806      yelingjun    1   37      0
# 110  20180906       lidequan    1   68      1
# 111  20180918       jihongyi    1   70      1
# 112  20181107      guoheping    1   54      1
# 113  20181113     chenyuanru    1   66      0
# 114  20181120    wuzhengquan    1   59      0
# 115  20181201       meiyuhua    1   26      0
# 116  20181213   zhanghuiping    1   55      0
# 117  20181224    tangxinjuan    0   78      1
# 118  20190109      xuzhongyu    1   62      0
# 119  20190114     xiexiuyang    1   61      0
# 120  20190131      guxiufang    0   58      1
# 121  20190301      hurenlong    1   72      0
# 122  20190308        lixinbo    1   27      0
# 123  20190912       herenzhu    0   69      1
# 124  20191031     shahuiying    0   32      0
# 125  20200327      tangfuhua    1   65      1
# 126  20200720   chenshengtai    1   73      0
# 127  20200808      liangyiai    1   50      0
# 128  20200813     cenzhifang    0   60      1
# 129  20201013    wangmeizhen    0   67      0
# 130  20201222        zhangyu    0   48      1
# 131  20201223       xujinlan    0   86      1
# 132  20210106     linjiading    1   84      1
# 133  20210115     qianjinxiu    0   73      1
# 134  20210201       jiayuhua    0   57      1
# 135  20210313       linaxiao    0   64      0
# 151                                           0.012294
# 152                                           0.005046
# 153                                           0.007159
# 154                                           0.005529
# 155                                           0.004789
#
#      ADC.nii_wavelet2-LL_glszm_ZoneEntropy  \
# 108                               5.279471
# 109                               7.012295
# 110                               5.791237
# 111                               7.641396
# 112                               5.837166
# 113                               5.139792
# 114                               6.640045
# 115                               6.524745
# 116                               5.982691
# 117                               7.670452
# 118                               6.151643
# 119                               7.351357
# 120                               6.098471
# 121                               5.978417
# 122                               6.049564
# 123                               5.996997
# 124                               5.614663
# 125                               5.537825
# 126                               4.622171
# 127                               5.543815
# 128                               5.922136
# 129                               5.838201
# 130                               5.604374
# 131                               6.554448
# 132                               6.191407
# 133                               6.273051
# 134                               5.769821
# 135                               5.005963
# 136                               5.514165
# 137                               5.237383
# 138                               6.146648
# 139                               5.925084
# 140                               6.947463
# 141                               5.896990
# 142                               5.617686
# 143                               6.930818
# 144                               6.905578
# 145                               5.809399
# 146                               6.253468
# 147                               5.977177
# 148                               5.653036
# 149                               5.964704
# 150                               5.970022
# 151                               6.694930
# 152                               6.252418
# 153                               5.685877
# 154                               6.019795
# 155                               7.026626
#
#      ADC.nii_wavelet2-LL_glszm_ZonePercentage  \
# 108                                  0.194127
# 109                                  0.091593
# 110                                  0.303901
# 111                                  0.071697
# 112                                  0.265499
# 113                                  0.646209
# 114                                  0.131888
# 115                                  0.248272
# 116                                  0.322422
# 117                                  0.072707
# 118                                  0.310649
# 119                                  0.061263
# 120                                  0.138676
# 121                                  0.140464
# 122                                  0.199264
# 123                                  0.264187
# 124                                  0.205813
# 125                                  0.440722
# 126                                  0.672414
# 127                                  0.422638
# 128                                  0.298469
# 129                                  0.271579
# 130                                  0.345982
# 131                                  0.173118
# 132                                  0.212397
# 133                                  0.275841
# 134                                  0.284730
# 135                                  0.624161
# 136                                  0.354515
# 137                                  0.504373
# 138                                  0.252648
# 139                                  0.346312
# 140                                  0.085650
# 141                                  0.303448
# 142                                  0.255467
# 143                                  0.104662
# 144                                  0.168925
# 145                                  0.223916
# 146                                  0.218997
# 147                                  0.310178
# 148                                  0.179765
# 149                                  0.234362
# 150                                  0.270883
# 151                                  0.148116
# 152                                  0.199551
# 153                                  0.321053
# 154                                  0.091146
# 155                                  0.095238
#
#      ADC.nii_wavelet2-LL_glszm_ZoneVariance  \
# 108                              204.951910
# 109                             1429.027131
# 110                               40.706127
# 111                             4579.819588
# 112                               52.049255
# 113                                1.487969
# 114                              640.275472
# 115                               29.059182
# 116                               19.512536
# 117                             2463.506532
# 118                               16.083451
# 119                             8515.979774
# 120                              456.565940
# 121                             1410.300538
# 122                              294.155700
# 123                               47.166273
# 124                              352.669713
# 125                                5.366232
# 126                                0.916502
# 127                                7.214870
# 128                               35.825919
# 129                               33.829217
# 130                               16.433132
# 131                               90.701555
# 132                               99.468474
# 133                               47.870669
# 134                               60.249854
# 135                                1.099780
# 136                               20.944286
# 137                                4.791607
# 138                              105.506006
# 139                               14.856406
# 140                              747.754636
# 141                               32.109231
# 142                               69.493717
# 143                             1283.597045
# 144                              138.724210
# 145                              113.657352
# 143                             70.597895                            0.009152
# 144                             76.356982                            0.016986
# 145                             97.686111                            0.017021
# 146                             82.527986                            0.016651
# 147                            104.545661                            0.043863
# 148                             97.424028                            0.011908
# 149                            103.758630                            0.016769
# 150                             91.747723                            0.023565
# 151                             77.041072                            0.020149
# 152                             94.611756                            0.016186
# 153                            138.721059                            0.039827
# 154                             53.663616                            0.006733
# 155                             60.503973                            0.015067
#
#      ADC.nii_wavelet2-LL_ngtdm_Strength
# 108                            6.419591
# 109                            0.332754
# 110                            1.159084
# 111                            0.101825
# 112                            0.879473
# 113                            5.265589
# 114                            0.683648
# 115                            0.924114
# 116                            2.524114
# 117                            0.190046
# 118                            2.501952
# 119                            0.114153
# 120                            0.814291
# 121                            0.552711
# 122                            0.932095
# 123                            1.658633
# 124                            1.147087
# 125                            5.307024
# 126                            5.840472
# 127                            1.775897
# 128                            4.908292
# 129                            2.391392
# 130                            5.890712
# 131                            2.655181
# 132                            1.639907
# 133                            2.192346
# 134                            1.794273
# 135                            6.294008
# 136                            1.658426
# 137                            3.774278
# 138                            1.330349
# 139                            1.426322
# 140                            0.721313
# 141                            0.909770
# 142                            1.165846
# 143                            0.305845
# 144                            0.354542
# 145                            1.290612
# 146                            1.517663
# 147                            4.308022
# 148                            0.956606
# 149                            2.258236
# 150                            3.495150
# 151                            1.219633
# 152                            1.737529
# 153                            3.469740
# 154                            2.222514
# 155                            0.543211
#
# [48 rows x 1042 columns]

# %% [markdown]
# # 正则匹配

# %%
filepath=r'\\mega\syli\dataset\EC_all\yuchuli'
zong=pd.read_csv(filepath+'\\T1_3.csv')
feature_list=['log-sigma','wave','original']
df3=zong.iloc[:,:2]

for feature in feature_list:
    os.makedirs(filepath+f"\\{feature}\\result")
    df1=zong.filter(regex='^(?!.*?firstorder).*$')   #^不匹配，?!不包含,.*?非贪婪，.*所有内容
#df4=zong.filter(regex='firstorder') 
    df2=df1.filter(regex=f'{feature}')
    result_df=pd.merge(df3,df2,left_index=True,right_index=True)
    result_df.to_csv(filepath+f'\\{feature}\\T1_3.csv',index=False)
    
df4=zong.filter(regex='firstorder')
df5=df4.filter(regex='^(?!.*?original).*$')
pd.merge(df3,df5,left_index=True,right_index=True).to_csv(filepath+'\\bian_firstorder\\T1_3.csv',index=False)
df5=df4.filter(regex='original')
df3=zong.iloc[:,:3]
pd.merge(df3,df5,left_index=True,right_index=True).to_csv(filepath+'\\ori_firstorder\\T1_3.csv',index=False)

# %%
#提取建模选好的特征并合并
number = 4
feature_path=['']*number
df_path=['']*number
select_df=['']*number
feature_path[0]=r'C:\Users\Administrator\Desktop\wuguan\junhenghua\t1\result\MinMax\PCC\RFE_2\RFE_train_feature.csv'
df_path[0]=r'C:\Users\Administrator\Desktop\wuguan\junhenghua\t1\test.csv'
feature_path[1]=r'C:\Users\Administrator\Desktop\wuguan\junhenghua\t2\result\MinMax\PCC\RFE_8\RFE_train_feature.csv'
df_path[1]=r'C:\Users\Administrator\Desktop\wuguan\junhenghua\t2\test.csv'
feature_path[2]=r'C:\Users\Administrator\Desktop\wuguan\junhenghua\t1_c\result\Mean\PCC\RFE_5\RFE_train_feature.csv'
df_path[2]=r'C:\Users\Administrator\Desktop\wuguan\junhenghua\t1_c\test.csv'
feature_path[3]=r'C:\Users\Administrator\Desktop\wuguan\junhenghua\ADC\zong\result\Mean\PCC\Relief_6\Relief_train_feature.csv'
df_path[3]=r'C:\Users\Administrator\Desktop\wuguan\junhenghua\ADC\zong\test.csv'
# feature_path[4]=r'\\mega\syli\dataset\neimo\data\T2_result\Zscore\PCC\Relief_3\feature_select_info.csv'
# df_path[4]=r'\\mega\syli\dataset\neimo\data\T2.csv' 
for i in range(number):
    print(i)
    feature_df=pd.read_csv(feature_path[i])
    feature=list(feature_df) #索引行并转换为列表
    data_df=pd.read_csv(df_path[i])
    feature.pop(0)   #出列
    feature.insert(0,'CaseName')  #入栈
    select_df[i]=data_df[feature]
    if i == 0:
        zong_df = select_df[i]
    else:
        zong_df = pd.merge(zong_df,select_df[i],on=('CaseName','label'))
        
zong_df.to_csv(r'C:\Users\Administrator\Desktop\wuguan\junhenghua\all\new\test.csv',index=False)
#info.rename(columns={'MRI-id':'CaseName'},inplace=True)  #改名
# Out:
# 0
# 1
# 2
# 3

# %%
zong_df
# Out:
#         CaseName  label  t1.nii_original_firstorder_Minimum  \
# 0        wuyilin      1                            0.087087
# 1       luyunchu      0                            0.065417
# 2       wanyimin      0                            0.008375
# 3     liubaoxian      0                            0.036295
# 4      zhanghong      0                            0.184426
# ..           ...    ...                                 ...
# 105    fengmeidi      1                            0.090692
# 106  shenpengfei      0                            0.090375
# 107   zhangyamei      0                            0.155577
# 108  tangdeliang      0                            0.071835
# 109   sunguiying      0                            0.007040
#
#      t1.nii_original_shape_Sphericity  sex  \
# 0                            0.468305    1
# 1                            0.410000    1
# 2                            0.351049    1
# 3                            0.379259    0
# 4                            0.429386    1
# ..                                ...  ...
# 105                          0.506083    0
# 106                          0.438210    1
# 107                          0.669130    0
# 108                          0.514738    1
# 109                          0.371823    0
#
#      t2.nii_original_firstorder_Minimum  t2.nii_original_shape_Sphericity  \
# 0                              0.081550                          0.468305
# 1                              0.006965                          0.479641
# 2                              0.041257                          0.462385
# 3                              0.001650                          0.379259
# 4                              0.184257                          0.429386
# ..                                  ...                               ...
# 105                            0.011241                          0.506083
# 106                            0.078399                          0.539253
# 107                            0.249633                          0.669130
# 108                            0.096908                          0.514738
# 109                            0.008508                          0.409617
#
#      t2.nii_wavelet-LH_glcm_ClusterProminence  \
# 0                                  181.942693
# 1                                   83.406020
# 2                                  254.963994
# 3                                  120.653996
# 4                                  170.858049
# ..                                        ...
# 105                                 96.637512
# 106                                113.115678
# 107                                725.027157
# 108                                266.543319
# 109                                310.931817
#
#      t2.nii_wavelet-LH_glcm_ClusterShade  \
# 0                               3.663487
# 1                               1.976193
# 2                              -0.153241
# 3                               0.169616
# 4                               3.849190
# ..                                   ...
# 105                             1.619189
# 106                             1.132558
# 107                             2.094700
# 108                            -1.008587
# 109                             8.036728
#
#      t2.nii_wavelet2-LH_firstorder_90Percentile  \
# 0                                      0.027328
# 1                                      0.024685
# 2                                      0.014813
# 3                                      0.035597
# 4                                      0.023074
# ..                                          ...
# 105                                    0.063963
# 106                                    0.050222
# 107                                    0.035347
# 108                                    0.059061
# 109                                    0.019212
#
#      t2.nii_wavelet2-LH_firstorder_Variance  \
# 0                                  0.000735
# 1                                  0.000794
# 2                                  0.000273
# 3                                  0.000957
# 4                                  0.000463
# ..                                      ...
# 105                                0.003245
# 106                                0.002353
# 107                                0.000956
# 108                                0.003352
# 109                                0.000686
#
#      t2.nii_wavelet2-LL_firstorder_Minimum
# 0                                 0.357915
# 1                                -0.066031
# 2                                 0.196506
# 3                                 0.052287
# 4                                 0.771441
# ..                                     ...
# 105                               0.161521
# 106                               0.770398
# 107                               1.104409
# 108                               0.418080
# 109                               0.033961
#
# [110 rows x 12 columns]

# %% [markdown]
# # 表格相关操作

# %%
#提取表格信息转为列表
path=r'D:\python\dataset\GBM-radiomics\GBM数据增加病例拼音.xlsx'
df1=pd.read_excel(path)
p53=df1['p53百分比'].values.tolist()
p53_label=df1['p53（0=≤50%；1=＞50%）'].values.tolist()
MGMT=df1['MGMT（0=≤8%；1=＞8%）'].values.tolist()
p53_1=df1['p53_1'].values.tolist()
p53_2=df1['p53_2'].values.tolist()

# %%
from math import sqrt
 
def multipl(a,b):
    sumofab=0.0
    for i in range(len(a)):
        temp=a[i]*b[i]
        sumofab+=temp
    return sumofab
 
def corrcoef(x,y):
    n=len(x)
    #求和
    sum1=sum(x)
    sum2=sum(y)
    #求乘积之和
    sumofxy=multipl(x,y)
    #求平方和
    sumofx2 = sum([pow(i,2) for i in x])
    sumofy2 = sum([pow(j,2) for j in y])
    num=sumofxy-(float(sum1)*float(sum2)/n)
    #计算皮尔逊相关系数
    den=sqrt((sumofx2-float(sum1**2)/n)*(sumofy2-float(sum2**2)/n))
    return num/den
print(corrcoef(p53_label,MGMT))
print(corrcoef(p53_1,MGMT))
print(corrcoef(p53_2,MGMT))

# %%
#多模态合并计算
path=r'\\mega\syli\dataset\Primary and metastatic'
df1=pd.read_csv(path+'\\T1\\T1_gai.csv')
T1CE_feature=pd.read_csv(path+'\\T1CE\\T1CE_gai.csv')
T2_feature=pd.read_csv(path+'\\T2\\T2_gai.csv')
DWI_feature=pd.read_csv(path+'\\DWI\\DWI_gai1.csv')
df1=pd.merge(df1,T2_feature)
df1=pd.merge(df1,T1CE_feature)
df1=pd.merge(df1,DWI_feature)
df1

# %%
#计算p值
import numpy as np
from scipy.stats import chi2_contingency

d = np.array([[0, 1,1], [0, 1]])
tab = pd.crosstab(x, y).fillna(0)
chi2_contingency(d)

# %%
#分割特征
filepath=r'D:\python\dataset\GBM-radiomics'
list1=['CBV','DSC','FLAIR-2','T1-1','T2-1']
for file_name in list1:
    path=filepath+'\\'+file_name+'\\firstorder'
#     os.mkdir(path+'\\ori_result')
#     os.mkdir(path+'\\bian_result')
    for form_path in ['\\train_numeric_feature.csv','\\test_numeric_feature.csv']:
        form=path+form_path
        zong=pd.read_csv(form)
        df1=zong.filter(regex='^(?!.*?original).*$')   #^不匹配，?!不包含,.*?非贪婪，.*所有内容
        df2=zong.filter(regex='original') 
        df3=zong.iloc[:,:2]
        df5=pd.merge(df3,df2,left_index=True,right_index=True)
        df1.to_csv(path+'\\bian_'+form_path[1:],index=False)
        df5.to_csv(path+'\\ori_'+form_path[1:],index=False)

# %%
# df4=df2.filter(regex='^(?!.*?firstorder).*$')   #^不匹配，?!不包含,.*?非贪婪，.*所有内容
# df6=df4.filter(regex='wave')  log-sigma-1-0,original
#也是分割特征
filepath=r'D:\python\dataset\GBM-radiomics\ki67\T1-3'
zong=pd.read_csv(filepath+'\\T1_3.csv')
feature_list=['log-sigma-1-0','log-sigma-3-0','log-sigma-5-0','wave','original']
df3=zong.iloc[:,:2]

for feature in feature_list:
    os.mkdir(filepath+f"\\{feature}")
    df1=zong.filter(regex='^(?!.*?firstorder).*$')   #^不匹配，?!不包含,.*?非贪婪，.*所有内容
#df4=zong.filter(regex='firstorder') 
    df2=df1.filter(regex=f'{feature}')
    result_df=pd.merge(df3,df2,left_index=True,right_index=True)
    result_df.to_csv(filepath+f'\\{feature}\\T1_3.csv',index=False)
    
df4=zong.filter(regex='firstorder')
df5=df4.filter(regex='^(?!.*?original).*$')
pd.merge(df3,df5,left_index=True,right_index=True).to_csv(filepath+'\\bian_firstorder\\T1_3.csv',index=False)
df5=df4.filter(regex='original')
df3=zong.iloc[:,:3]
pd.merge(df3,df5,left_index=True,right_index=True).to_csv(filepath+'\\ori_firstorder\\T1_3.csv',index=False)

# %%
#变换label
path = r'\\mega\syli\dataset\endometrial cancer'
label_df = pd.read_excel(os.path.join(path,'EC分子分型8.61（1）.xlsx'))
label_df = label_df[['CaseName', 'label']]
i = 0
for a in label_df['label']:
    if 'P53' in a:
        label_df.loc[i, 'label'] = 1
    else:
        label_df.loc[i, 'label'] = 0
    i = i+1
label_df.to_csv(r'\\mega\syli\dataset\endometrial cancer\label1.csv',index=False,encoding="utf_8_sig")

# %%
#合并label和feature
path=r'\\mega\syli\dataset\Primary and metastatic\test\T1\T1_feature_4.csv'
label_path=r'\\mega\syli\dataset\Primary and metastatic\info.csv'
df1=pd.read_csv(path)   #可设置stp
df2=pd.read_csv(label_path)[['CaseName','label']]
df5=pd.merge(df2,df1)   #合并数据表,需要共同的列
#df2.insert(1,'label',df3)  #插入列
df5.to_csv(r'\\mega\syli\dataset\Primary and metastatic\test\T1\minmax_4\T1.csv',index=False,encoding="utf_8_sig")
#os.mkdir(r'\\mega\syli\dataset\endometrial cancer\data' + f'\\{modal}_result')

# %%
#特征表提取文件有的
key = 'MRID'
dirs = os.listdir(r'\\mega\syli\dataset\EC_seg\process_lnm_new\process_lnm_new')
dirs_df = pd.DataFrame(dirs, columns=[key], dtype='str')
df = pd.read_excel(r'\\mega\MRIData\Red-House\EC_seg\lnm positive_1.xlsx', sheet_name='合计', dtype='str')
fin_df = pd.merge(dirs_df, df, on=key)
fin_df.to_csv(r'\\mega\syli\dataset\EC_seg\process_lnm_new\new_info.csv',index=False,encoding="utf_8_sig")

# %%
#多个表格提取数据
import pandas as pd
import numpy as np
import os
filespath = r'\\mega\syli\dataset\EC_all_process_data'
files = os.listdir(filespath)
files_1 = [x for x in files if 'y' not in x]
files_df_1 = pd.DataFrame(files_1, columns=['ID'], dtype='int64')
files_df_2 = pd.DataFrame(files, columns=['ID'])
#files_df = pd.to_numeric(files_df)
df1 = pd.read_excel('//mega\syli\dataset/all_frame/biao1.xlsx')
df1.rename(columns={'病案号':'ID'}, inplace=True)
sum_df = df1[['ID','淋巴结转移阳性','出院日期','发病年龄','身高','体重','病理类型']]
df2 = pd.read_excel('//mega\syli\dataset/all_frame/biao2.xlsx')
df2.rename(columns={'病案号':'ID'}, inplace=True)
sum_df = pd.concat([sum_df,df2[['ID','淋巴结转移阳性','出院日期','发病年龄','身高','体重','病理类型']]])
df3 = pd.read_excel('//mega\syli\dataset/all_frame/biao3.xlsx')
df3.rename(columns={'影像号':'ID'}, inplace=True)
sum_df = pd.concat([sum_df,df3[['ID','淋巴结转移阳性','出院日期','发病年龄','身高','体重','病理类型']]])
df4 = pd.read_excel('//mega\syli\dataset/all_frame/biao4.xlsx')[['MRID','淋巴结转移阳性','手术日期','发病年龄','身高','体重','病理类型']]
df4.rename(columns={'MRID':'ID','手术日期':'出院日期'}, inplace=True)
#df4 = df4[~df4['ID'].isin(['5346549'])]
sum_df = pd.concat([sum_df,df4])
all_df_1 = pd.merge(files_df_1, sum_df)
all_df_2 = pd.merge(files_df_2, sum_df)
all_df = pd.concat([all_df_1, all_df_2])
#all_df.drop_duplicates(subset=['ID','淋巴结转移阳性','出院日期','发病年龄','身高','体重','病理类型'], keep='first', inplace=True)
all_df.to_excel(r'\\mega\syli\dataset\all_frame/fin_df_1.xlsx', index=False)

# %%
import pandas as pd
my_df = pd.read_excel(r'\\mega\syli\dataset\all_frame\fin_df_1.xlsx')
jie_df = pd.read_csv(r'C:\Users\handsome\Documents\WeChat Files\wxid_hncq0l75v1pq21\FileStorage\File\2022-03\lnm_label.csv')
a = my_df['ID'].values.tolist()
a = [str(i) for i in a]
my_df['ID'] = a
b = jie_df['ID'].values.tolist()
print(list(set(a).difference(set(b))))
print(list(set(b).difference(set(a))))
# my_df = my_df.set_index('ID')
# jie_df = jie_df.set_index('ID')
new_df = pd.merge(my_df, jie_df)
for index, row in new_df.iterrows():
    if row['label'] != row['淋巴结转移阳性']:
        #my_df.loc[index, '淋巴结转移阳性'] = row['label']
        print(index, row['label'], row['淋巴结转移阳性'])
#my_df.to_excel(r'\\mega\syli\dataset\all_frame/fin_df_2.xlsx', index=False)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-12-7a3a4b2565f8> in <module>
#       1 import pandas as pd
# ----> 2 my_df = pd.read_excel(r'\\mega\syli\dataset\all_frame\fin_df.xlsx')
#       3 jie_df = pd.read_csv(r'C:\Users\handsome\Documents\WeChat Files\wxid_hncq0l75v1pq21\FileStorage\File\2022-03\lnm_label.csv')
#       4 a = my_df['ID'].values.tolist()
#       5 a = [str(i) for i in a]
#
# D:\env\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     297                 )
#     298                 warnings.warn(msg, FutureWarning, stacklevel=stacklevel)
# --> 299             return func(*args, **kwargs)
#     300
#     301         return wrapper
#
# D:\env\lib\site-packages\pandas\io\excel\_base.py in read_excel(io, sheet_name, header, names, index_col, usecols, squeeze, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, thousands, comment, skipfooter, convert_float, mangle_dupe_cols, storage_options)
#     334     if not isinstance(io, ExcelFile):
#     335         should_close = True
# --> 336         io = ExcelFile(io, storage_options=storage_options, engine=engine)
#     337     elif engine and engine != io.engine:
#     338         raise ValueError(
#
# D:\env\lib\site-packages\pandas\io\excel\_base.py in __init__(self, path_or_buffer, engine, storage_options)
#    1069                 ext = "xls"
#    1070             else:
# -> 1071                 ext = inspect_excel_format(
#    1072                     content=path_or_buffer, storage_options=storage_options
#    1073                 )
#
# D:\env\lib\site-packages\pandas\io\excel\_base.py in inspect_excel_format(path, content, storage_options)
#     947     assert content_or_path is not None
#     948
# --> 949     with get_handle(
#     950         content_or_path, "rb", storage_options=storage_options, is_text=False
#     951     ) as handle:
#
# D:\env\lib\site-packages\pandas\io\common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     649         else:
#     650             # Binary mode
# --> 651             handle = open(handle, ioargs.mode)
#     652         handles.append(handle)
#     653
#
# FileNotFoundError: [Errno 2] No such file or directory: '\\\\mega\\syli\\dataset\\all_frame\\fin_df.xlsx'

# %%
#给表格额外加数据
import pandas as pd
import numpy as np
import os
old_df = pd.read_excel(r'\\mega\syli\dataset\EC_all\all_frame\fin_df.xlsx')
new_df_1 = pd.read_excel(r'\\mega\syli\dataset\EC_all\all_frame\ori\biao4.xlsx')[['ID', '脉管内癌栓']]
new_df_2 = pd.read_excel(r'\\mega\syli\dataset\EC_all\all_frame\ori\biao6.xlsx')[['ID', '脉管内癌栓']]
# for index, row in new_df_2.iterrows():
#     #new_df_2.loc[index, 'ID'] = row['ID'][1:]
#     print(row['ID'])
old_df['ID'] = old_df['ID'].astype(dtype='str')
new_df_2['ID'] = new_df_2['ID'].astype(dtype='str')
print(new_df_2.head())
all_df_1 = pd.merge(old_df, new_df_1)
all_df_2 = pd.merge(old_df, new_df_2)
all_df = pd.concat([all_df_1, all_df_2])
print(all_df)

#all_df.to_excel(r'\\mega\syli\dataset\all_frame/fin_df_1.xlsx', index=False)
# Out:
#         ID 脉管内癌栓
# 0  2087438     0
# 1  2119112     0
# 2  4070493     0
# 3  4078034     0
# 4  4078377     1
#             ID  淋巴结转移阳性        出院日期  发病年龄     身高    体重         病理类型 脉管内癌栓
# 0    y00131065        1  20161106.0  65.0    NaN   NaN       999999   0.0
# 1    y00002416        1  20190122.0  62.0  160.0  83.0            1   1.0
# 2    y00002580        1  20190214.0  61.0  166.0  65.0            1   1.0
# 3    y00004593        1  20190226.0  53.0  147.0  62.0            1   1.0
# 4    y00004585        1  20190304.0  39.0    NaN   NaN            1   1.0
# ..         ...      ...         ...   ...    ...   ...          ...   ...
# 533    5677498        0  20180322.0  50.0  155.0  60.0            1     0
# 534    5671128        0  20180325.0  36.0    NaN   NaN            1     0
# 535    5229971        0         NaN  26.0  160.0  62.0  子宫不典型息肉状腺肌瘤     0
# 536    5229971        0         NaN  26.0  160.0  62.0  子宫不典型息肉状腺肌瘤     0
# 537    5614039        0         NaN  56.0    NaN   NaN            1     1
#
# [592 rows x 8 columns]

# %%
#改名
import os
from pathlib import Path
dir_path = r'\\mega\MRIData\Red-House\EC_all_process_data'
case_list = [i for i in Path(dir_path).iterdir()]
for case in case_list:
    file_list = [i for i in Path(case).iterdir()]
    for file in file_list:
        if 'T2_SAG' in file.name:
            os.rename(file, str(file).replace('T2_SAG', 'T2'))

# %%
feature_path=r'\\mega\syli\dataset\EC_all\yuchuli\T1CE\original\texture\result\Mean\PCC\KW_12\KW_train_feature.csv'
df = pd.read_csv(feature_path)
df.columns[2:].values.tolist()
# Out:
# ['T1CE.nii_original_glcm_Correlation',
#  'T1CE.nii_original_glcm_Id',
#  'T1CE.nii_original_glcm_Imc1',
#  'T1CE.nii_original_glcm_Imc2',
#  'T1CE.nii_original_gldm_DependenceEntropy',
#  'T1CE.nii_original_gldm_DependenceVariance',
#  'T1CE.nii_original_gldm_LargeDependenceLowGrayLevelEmphasis',
#  'T1CE.nii_original_glrlm_LongRunEmphasis',
#  'T1CE.nii_original_glrlm_RunEntropy',
#  'T1CE.nii_original_glszm_LargeAreaLowGrayLevelEmphasis',
#  'T1CE.nii_original_glszm_ZoneEntropy',
#  'T1CE.nii_original_ngtdm_Complexity']
